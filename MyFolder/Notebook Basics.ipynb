# %%
print("Hello World !")

# %%
# %sql
SELECT "Hello from SQL!" as command

# %% [markdown]
# #Title1
# ##Titile2
# ###Title3

# %%
# %run ./Includes/setup

# %%
print(fullname)

# %%
# %fs ls '/databricks-datasets'

# %%
dbutils .help()

# %%
dbutils.fs.help()
dbutils.fs.ls("dbfs:/")

# %%
files= dbutils.fs.ls('databricks-datasets')
display(files)
